# %%
list_one = [1, 2, 3, 4, 'Depi', 'machinelearning', True, [1, 2, 3, "true", ['ml','dl', 'llm']]]

print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one[7][4][1]
# Out:
# 'dl'

# %%
list_one[7][4][0] = 'DS'
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'machinelearning',
#  True,
#  [1, 2, 3, 'true', ['DS', 'dl', 'llm']]]

# %%
faris = list('fahd')
print(faris)
# Out:
# ['f', 'a', 'h', 'd']

# %%
list_1 = ['ml', 'dl', 'llm']
list_1.append('ai')
print(list_1)
# Out:
# ['ml', 'dl', 'llm', 'ai']

# %%
list_1.insert(0, 'deeplearning')
print(list_1)
# Out:
# ['deeplearning', 'ml', 'dl', 'llm', 'ai']

# %%
list_1.extend("faris")
list_1
# Out:
# ['deeplearning', 'ml', 'dl', 'llm', 'ai', 'f', 'a', 'r', 'i', 's']

# %%
list_1.remove('ml')
list_1
# Out:
# ['deeplearning', 'dl', 'llm', 'ai', 'f', 'a', 'r', 'i', 's']

# %%
list_2 = list_1.pop()
list_2
# Out:
# 's'

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print(f"my name is {name},and my age is {age}")
# Out:
# my name is faris,and my age is 21

# %%
input_list = [
    "amit",
    "learning",
    "python",
    "machine learning",
    "data science",
    "deep learning"
]

item = input("Enter your item: ")
input_list.remove(item)
print(f"Item {item} has been removed from the list.")
print(input_list)
# Out:
# Item amit has been removed from the list.
# ['learning', 'python', 'machine learning', 'data science', 'deep learning']

# %%
list_5 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
list_5.clear()
list_5
# Out:
# []

# %%
print(list_5)
# Out:
# []

# %%
tuple_1 = (1, 2, 3, 4, 5)
tuple_1[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 tuple_1 = (1, 2, 3, 4, 5)
# ----> 2 tuple_1[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
x ={1, 2, 3, 4, 5}
x[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 x ={1, 2, 3, 4, 5}
# ----> 2 x[0] = 10
#
# TypeError: 'set' object does not support item assignment

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)

if num2 != 0:
    print("Division:", num1 / num2)
else:
    print("Division: Cannot divide by zero.")
# Out:
# Addition: 15.0
# Subtraction: -5.0
# Multiplication: 50.0
# Division: 0.5

# %%
degree = float(input("Enter the student's degree: "))

if 90 <= degree <= 100:
    print("Grade: A")
elif 80 <= degree < 90:
    print("Grade: B")
elif 70 <= degree < 80:
    print("Grade: C")
elif 60 <= degree < 70:
    print("Grade: D")
elif 0 <= degree < 60:
    print("Grade: F")
else:
    print("Invalid degree")
# Out:
# Grade: B
