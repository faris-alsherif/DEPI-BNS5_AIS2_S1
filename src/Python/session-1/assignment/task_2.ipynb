# %% [markdown]
# <h1>Task1<h1>

# %% [markdown]
# <h3>first point</h3>

# %%
email = "Amit_ml@gmail.com"

# %%
check1 = email.count('@') == 1
domin = email[email.find('@')+1:]
check2 = domin.count('.') >= 1

# %%
if check1 and check2:
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Valid email

# %% [markdown]
# <h3>Second point</h3>

# %%
Username = email[:email.find('@')]
Username
# Out:
# 'Amit_ml'

# %% [markdown]
# <h3>third point</h3>

# %%
Domin = email[email.find('@')+1:email.find('.')]
Domin
# Out:
# 'gmail'

# %% [markdown]
# <h3>fourth point</h3>

# %%
if email.endswith(".com"):
    print('Commercial domain')
elif email.endswith(".edu"):
    print('Educational domain')
else:
    print('othter domain')
# Out:
# Commercial domain

# %% [markdown]
# <h1>Task2<h1>

# %%
encoded_message = "###!!@mocleW EPGTQ!!!6789"
core_part = encoded_message[6:18]
core_part
# Out:
# 'mocleW EPGTQ'

# %%
first_word = core_part.split()[0][::-1]
first_word
# Out:
# 'Welcom'

# %%
Second_word = core_part.split()[1][1::]
Second_word
# Out:
# 'PGTQ'

# %%
Decoded_message = first_word+' '+Second_word
Decoded_message
# Out:
# 'Welcom PGTQ'

# %% [markdown]
# <h1>Task3</h1>

# %%
encoded_message2 = "&&&**$gnirtS PLIO!!@1234"
core_part2 = encoded_message2[6:17]
core_part2
# Out:
# 'gnirtS PLIO'

# %%
first_word2 = core_part2.split()[0][::-1]
first_word2
# Out:
# 'String'

# %%
Second_word2 = core_part2.split()[1].replace('I','E')
Second_word2 = Second_word2.replace('O','U')
Second_word2
# Out:
# 'PLEU'

# %%
Decoded_message2 = first_word2+' '+Second_word2
Decoded_message2
# Out:
# 'String PLEU'

# %% [markdown]
# <h1>Task4</h1>

# %%
encoded_message3 = "##$$$@!yalpstcejorp EPUVT****9887"
core_part3 = encoded_message3[7:25]
core_part3
# Out:
# 'yalpstcejorp EPUVT'

# %%
first_word3 = core_part3.split()[0][::-1]
first_word3
# Out:
# 'projectsplay'

# %%
Second_word3 = core_part3.split()[1].replace('E','A')
Second_word3 = Second_word3.replace('U','O')
Second_word3
# Out:
# 'APOVT'

# %%
Decoded_message3 = first_word3+' '+Second_word3
Decoded_message3
# Out:
# 'projectsplay APOVT'
